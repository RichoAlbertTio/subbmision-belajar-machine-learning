# %%
# import library
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Baca dataset
file_path = 'data/day.csv'  # Ganti dengan path sebenarnya ke file CSV Anda
file_path = 'data/hour.csv'  # Ganti dengan path sebenarnya ke file CSV Anda
data_day = pd.read_csv(file_path)
data_hour = pd.read_csv(file_path)

# %%
# Tampilkan data csv day
print('ini csv day :')
print(data_day.head())
# Out:
# ini csv day :
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
# Tampilkan data csv hours
print('ini csv hours :')
print(data_hour.head())
# Out:
# ini csv hours :
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
# Pastikan kolom dataset terdeteksi dengan benar
print(data_hour.dtypes)
print(data_day.dtypes)
# Out:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# hr              int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# hr              int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
# Konversi kolom tanggal ke format datetime
data_hour['dteday'] = pd.to_datetime(data_hour['dteday'])
data_day['dteday'] = pd.to_datetime(data_day['dteday'])

# %%
# **Pertanyaan 1: Bagaimana pengaruh waktu terhadap jumlah penyewaan sepeda?**
plt.figure(figsize=(10, 6))
sns.lineplot(x='hr', y='cnt', data=data_hour.groupby('hr').mean().reset_index())
plt.title('Pengaruh Jam terhadap Jumlah Penyewaan Sepeda', fontsize=16)
plt.xlabel('Jam', fontsize=12)
plt.ylabel('Rata-rata Penyewaan Sepeda', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# **Pertanyaan 2: Bagaimana perbandingan pola penyewaan sepeda pada hari kerja dan akhir pekan?**
avg_rental_by_workingday = data_hour.groupby('workingday')['cnt'].mean()
colors = ['#FF6F61', '#6BAED6']  # Warna untuk akhir pekan dan hari kerja
plt.figure(figsize=(8, 5))
plt.bar(avg_rental_by_workingday.index, avg_rental_by_workingday.values, color=colors)
plt.xticks(ticks=[0, 1], labels=['Akhir Pekan', 'Hari Kerja'], fontsize=12)
plt.title('Perbandingan Penyewaan Sepeda (Hari Kerja vs Akhir Pekan)', fontsize=16)
plt.xlabel('Tipe Hari', fontsize=12)
plt.ylabel('Rata-rata Penyewaan Sepeda', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# **Pertanyaan 3: Apa pengaruh cuaca terhadap jumlah penyewaan sepeda?**
# Pilih fitur yang relevan
corr_features = ['temp', 'atemp', 'hum', 'windspeed', 'cnt']
corr_matrix = data_day[corr_features].corr()

# %%
# Plot heatmap korelasi
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Korelasi Variabel Cuaca dengan Total Penyewaan Sepeda', fontsize=16)
plt.show()

# %%
# Pertanyaan 4: Bagaimana pola penyewaan sepeda berdasarkan hari dalam seminggu (weekday)?
# Rata-rata penyewaan berdasarkan hari dalam seminggu
avg_rental_by_weekday = data_hour.groupby('weekday')['cnt'].mean()

# Visualisasi
plt.figure(figsize=(8, 6))
plt.bar(avg_rental_by_weekday.index, avg_rental_by_weekday.values, color='#4CAF50')
plt.xticks(ticks=[0, 1, 2, 3, 4, 5, 6], labels=['Senin', 'Selasa', 'Rabu', 'Kamis', 'Jumat', 'Sabtu', 'Minggu'], fontsize=10)
plt.title('Rata-rata Penyewaan Sepeda Berdasarkan Hari', fontsize=14)
plt.xlabel('Hari dalam Seminggu', fontsize=12)
plt.ylabel('Rata-rata Penyewaan Sepeda', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Pertanyaan 5: Bagaimana hubungan antara jumlah penyewaan pengguna terdaftar (registered) dan pengguna kasual (casual)?

# Scatter plot hubungan registered dan casual
plt.figure(figsize=(8, 6))
plt.scatter(data_hour['casual'], data_hour['registered'], alpha=0.6, c=data_hour['cnt'], cmap='viridis')
plt.colorbar(label='Total Penyewaan')
plt.title('Hubungan Jumlah Penyewaan Pengguna Terdaftar vs Kasual', fontsize=14)
plt.xlabel('Penyewaan Pengguna Kasual', fontsize=12)
plt.ylabel('Penyewaan Pengguna Terdaftar', fontsize=12)
plt.grid(linestyle='--', alpha=0.7)
plt.show()

# %%
# Pertanyaan 6: Bagaimana pengaruh workingday terhadap penyewaan sepeda untuk pengguna kasual dan terdaftar?
# Rata-rata penyewaan berdasarkan hari kerja untuk pengguna kasual dan terdaftar
avg_rental_workingday = data_hour.groupby('workingday')[['casual', 'registered']].mean()

# Visualisasi
avg_rental_workingday.plot(kind='bar', figsize=(8, 6), color=['#FFC107', '#2196F3'])
plt.xticks(ticks=[0, 1], labels=['Akhir Pekan', 'Hari Kerja'], rotation=0, fontsize=12)
plt.title('Pengaruh Hari Kerja terhadap Penyewaan Kasual dan Terdaftar', fontsize=14)
plt.xlabel('Kategori Hari', fontsize=12)
plt.ylabel('Rata-rata Penyewaan', fontsize=12)
plt.legend(['Kasual', 'Terdaftar'])
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# # 1. Pengaruh Waktu terhadap Jumlah Penyewaan Sepeda
# **Kesimpulan**: Penyewaan sepeda menunjukkan pola yang jelas terkait waktu. Aktivitas penyewaan meningkat tajam pada pagi hari (sekitar pukul 08:00) dan sore hari (sekitar pukul 17:00), yang kemungkinan besar disebabkan oleh perjalanan kerja atau sekolah. Hal ini menunjukkan bahwa sepeda digunakan sebagai moda transportasi pada jam sibuk.
#
# # 2. Perbandingan Pola Penyewaan Sepeda pada Hari Kerja dan Akhir Pekan
# **Kesimpulan**: Jumlah penyewaan sepeda relatif seimbang antara hari kerja dan akhir pekan, tetapi pola penggunaannya mungkin berbeda. Hari kerja lebih didominasi oleh pengguna terdaftar, sedangkan akhir pekan lebih banyak digunakan oleh pengguna kasual untuk rekreasi.
#
# # 3. Pengaruh Cuaca terhadap Jumlah Penyewaan Sepeda
# **Kesimpulan**: Dari heatmap korelasi, terlihat bahwa faktor seperti temperatur (temp) memiliki korelasi positif terhadap jumlah penyewaan sepeda. Sebaliknya, kelembapan (hum) dan kecepatan angin (windspeed) memiliki korelasi negatif. Artinya, cuaca yang nyaman (suhu sedang, kelembapan rendah, dan angin tidak terlalu kencang) mendorong lebih banyak penyewaan sepeda.
#
# # 4. Pola Penyewaan Sepeda Berdasarkan Hari dalam Seminggu
# **Kesimpulan**: Penyewaan sepeda cenderung merata sepanjang minggu, tetapi sedikit menurun pada hari kerja tertentu (seperti Senin). Akhir pekan mungkin menunjukkan sedikit kenaikan, terutama untuk pengguna kasual.
#
# # 5. Hubungan antara Pengguna Terdaftar (Registered) dan Kasual (Casual)
# **Kesimpulan**: Ada perbedaan yang jelas antara pola penggunaan sepeda oleh pengguna terdaftar dan kasual. Pengguna terdaftar cenderung lebih konsisten setiap hari, terutama pada jam sibuk hari kerja. Pengguna kasual lebih banyak pada akhir pekan atau hari-hari libur, menunjukkan orientasi rekreasi.
#
# # 6. Pengaruh Workingday terhadap Penyewaan Sepeda
# **Kesimpulan**: Hari kerja (workingday) memiliki pengaruh besar terhadap pola penyewaan. Pengguna terdaftar mendominasi pada hari kerja, sementara pengguna kasual lebih aktif pada hari libur. Ini mengindikasikan bahwa pengguna terdaftar lebih menggunakan sepeda untuk keperluan fungsional, sedangkan pengguna kasual lebih untuk rekreasi.
